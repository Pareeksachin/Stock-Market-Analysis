# %%
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()
import pandas as pd
from datetime import datetime,date
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
TSLA_data = pdr.get_data_yahoo("TSLA")
TSLA_data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-07-17  286.630005  292.230011  283.570007  290.380005  290.380005
# 2023-07-18  290.149994  295.260010  286.010010  293.339996  293.339996
# 2023-07-19  296.040009  299.290009  289.519989  291.260010  291.260010
# 2023-07-20  279.559998  280.929993  261.200012  262.899994  262.899994
# 2023-07-21  268.000000  268.000000  255.800003  260.019989  260.019989
#
#                Volume
# Date
# ...

# %%
type(TSLA_data)
# Out:
# pandas.core.frame.DataFrame

# %%
TSLA_data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-07-17  286.630005  292.230011  283.570007  290.380005  290.380005
# 2023-07-18  290.149994  295.260010  286.010010  293.339996  293.339996
# 2023-07-19  296.040009  299.290009  289.519989  291.260010  291.260010
# 2023-07-20  279.559998  280.929993  261.200012  262.899994  262.899994
# 2023-07-21  268.000000  268.000000  255.800003  260.019989  260.019989
#
#                Volume
# Date
# 2023-07-17  131569600
# 2023-07-18  112434700
# 2023-07-19  142355400
# 2023-07-20  175158300
# 2023-07-21  161050100

# %%
TSLA_data['High'].plot(figsize = (12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
### Xlimit and yLimit and colouring
TSLA_data['High'].plot(xlim = ['2020-01-01','2021-09-01'], ylim=[0,900],c = 'green', figsize = (12,4),ls = '--')
# Out:
# <Axes: xlabel='Date'>

# %%
TSLA_data.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2023-07-10', '2023-07-11', '2023-07-12', '2023-07-13',
#                '2023-07-14', '2023-07-17', '2023-07-18', '2023-07-19',
#                '2023-07-20', '2023-07-21'],
#               dtype='datetime64[ns]', name='Date', length=3288, freq=None)

# %%
index = TSLA_data.loc['2023-01-01':'2023-07-10'].index
index
# Out:
# DatetimeIndex(['2023-01-03', '2023-01-04', '2023-01-05', '2023-01-06',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-17',
#                ...
#                '2023-06-26', '2023-06-27', '2023-06-28', '2023-06-29',
#                '2023-06-30', '2023-07-03', '2023-07-05', '2023-07-06',
#                '2023-07-07', '2023-07-10'],
#               dtype='datetime64[ns]', name='Date', length=129, freq=None)

# %%
share_open = TSLA_data.loc['2023-01-01':'2023-07-10']['Open']

# %%
share_open
# Out:
# Date
# 2023-01-03    118.470001
# 2023-01-04    109.110001
# 2023-01-05    110.510002
# 2023-01-06    103.000000
# 2023-01-09    118.959999
#                  ...
# 2023-07-03    276.489990
# 2023-07-05    278.820007
# 2023-07-06    278.089996
# 2023-07-07    278.429993
# 2023-07-10    276.470001
# Name: Open, Length: 129, dtype: float64

# %%
figure,axis = plt.subplots()
axis.plot(index,share_open)
plt.show()
### preventing overlapping of dates : figure.autofmt_xdate()
## plt.tight_layout()

# %%
axis
# Out:
# <Axes: >

# %%
### DateTime index
TSLA_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3288 entries, 2010-06-29 to 2023-07-21
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3288 non-null   float64
#  1   High       3288 non-null   float64
#  2   Low        3288 non-null   float64
#  3   Close      3288 non-null   float64
#  4   Adj Close  3288 non-null   float64
#  5   Volume     3288 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 308.9 KB

# %%
df = TSLA_data.reset_index()

# %%
TSLA_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3288 entries, 2010-06-29 to 2023-07-21
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3288 non-null   float64
#  1   High       3288 non-null   float64
#  2   Low        3288 non-null   float64
#  3   Close      3288 non-null   float64
#  4   Adj Close  3288 non-null   float64
#  5   Volume     3288 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 308.9 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3288 entries, 0 to 3287
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       3288 non-null   datetime64[ns]
#  1   Open       3288 non-null   float64
#  2   High       3288 non-null   float64
#  3   Low        3288 non-null   float64
#  4   Close      3288 non-null   float64
#  5   Adj Close  3288 non-null   float64
#  6   Volume     3288 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 179.9 KB

# %%
pd.to_datetime(df['Date'])
# Out:
# 0      2010-06-29
# 1      2010-06-30
# 2      2010-07-01
# 3      2010-07-02
# 4      2010-07-06
#           ...
# 3283   2023-07-17
# 3284   2023-07-18
# 3285   2023-07-19
# 3286   2023-07-20
# 3287   2023-07-21
# Name: Date, Length: 3288, dtype: datetime64[ns]

# %%
## revert it to set index
df.set_index('Date',drop = True)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-07-17  286.630005  292.230011  283.570007  290.380005  290.380005
# 2023-07-18  290.149994  295.260010  286.010010  293.339996  293.339996
# 2023-07-19  296.040009  299.290009  289.519989  291.260010  291.260010
# 2023-07-20  279.559998  280.929993  261.200012  262.899994  262.899994
# 2023-07-21  268.000000  268.000000  255.800003  260.019989  260.019989
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %%
##create a date
datetime(2021,1,20)
# Out:
# datetime.datetime(2021, 1, 20, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 7, 24, 18, 42, 24, 47259)

# %% [markdown]
# #Time Sampling

# %%
TSLA_data.resample(rule='A').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    1.076000    1.108667    0.998667    1.053333    1.053333
# 2011-12-31    1.452000    1.484667    1.407333    1.455333    1.455333
# 2012-12-31    1.774667    1.790000    1.509333    1.519333    1.519333
# 2013-12-31    2.205333    2.225333    2.140667    2.194000    2.194000
# 2014-12-31    9.366667    9.800000    9.111333    9.289333    9.289333
# 2015-12-31   12.388667   12.619333   12.093333   12.333333   12.333333
# 2016-12-31    9.488000   10.331333    9.403333    9.578000    9.578000
# 2017-12-31   14.316667   14.688667   14.064000   14.466000   14.466000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# ...

# %%
TSLA_data.resample(rule='A').max()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    2.391333    2.428000    2.316667    2.364667    2.364667
# 2011-12-31    2.308667    2.333333    2.268667    2.329333    2.329333
# 2012-12-31    2.546000    2.663333    2.474000    2.534000    2.534000
# 2013-12-31   12.930667   12.966667   12.558000   12.891333   12.891333
# 2014-12-31   19.177999   19.427999   18.693333   19.069332   19.069332
# 2015-12-31   18.680000   19.110001   18.420000   18.817333   18.817333
# 2016-12-31   17.763332   17.955999   16.967333   17.694668   17.694668
# 2017-12-31   25.779333   25.974001   25.290001   25.666668   25.666668
# 2018-12-31   25.000000   25.830667   24.474667   25.304667   25.304667
# 2019-12-31   29.000000   29.020666   28.423332   28.729334   28.729334
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
# 2021-12-31  411.470001  414.496674  405.666656  409.970001  409.970001
# ...

# %%
## A = year and Frequency
TSLA_data.resample(rule='A').min()['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# if you want quartly
TSLA_data.resample(rule='QS')['Open'].min().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
## Business End Frequency
TSLA_data.resample(rule='BA').min()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-31    1.076000    1.108667    0.998667    1.053333    1.053333
# 2011-12-30    1.452000    1.484667    1.407333    1.455333    1.455333
# 2012-12-31    1.774667    1.790000    1.509333    1.519333    1.519333
# 2013-12-31    2.205333    2.225333    2.140667    2.194000    2.194000
# 2014-12-31    9.366667    9.800000    9.111333    9.289333    9.289333
# 2015-12-31   12.388667   12.619333   12.093333   12.333333   12.333333
# 2016-12-30    9.488000   10.331333    9.403333    9.578000    9.578000
# 2017-12-29   14.316667   14.688667   14.064000   14.466000   14.466000
# 2018-12-31   16.851999   17.355333   16.306000   16.704000   16.704000
# 2019-12-31   12.073333   12.445333   11.799333   11.931333   11.931333
# 2020-12-31   24.980000   26.990667   23.367332   24.081333   24.081333
# 2021-12-31  184.183334  188.736664  179.830002  187.666672  187.666672
# ...

# %%
TSLA_data.resample(rule='BA').min().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
TSLA_data['Open'].resample(rule='QS').max().plot(kind = 'bar',figsize = (15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
TSLA_data['High'].rolling(3).mean().head(10)
# Out:
# Date
# 2010-06-29         NaN
# 2010-06-30         NaN
# 2010-07-01    1.807556
# 2010-07-02    1.765333
# 2010-07-06    1.533778
# 2010-07-07    1.327333
# 2010-07-08    1.203333
# 2010-07-09    1.156667
# 2010-07-12    1.188667
# 2010-07-13    1.213556
# Name: High, dtype: float64

# %%
TSLA_data['Open : 30 Days Rolling'] = TSLA_data['Open'].rolling(30).mean()

# %%
TSLA_data.head(20)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 2010-07-12  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 2010-07-13  1.159333  1.242667  1.126667  1.209333   1.209333   40201500
# 2010-07-14  1.196000  1.343333  1.184000  1.322667   1.322667   62928000
# 2010-07-15  1.329333  1.433333  1.266667  1.326000   1.326000   56097000
# ...

# %%
 ## plotting
    
## Simple Moving Averages
TSLA_data[['Open','Open : 30 Days Rolling']].plot(figsize = (15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
TSLA_data['Open : 30 Days Moving Average'] = TSLA_data['Open'].rolling(window=30,min_periods=1).mean()
TSLA_data['Open : 50 Days Moving Average'] = TSLA_data['Open'].rolling(window=50,min_periods=1).mean()

# %%
TSLA_data.head(50)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 2010-07-07  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 2010-07-08  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 2010-07-09  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 2010-07-12  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 2010-07-13  1.159333  1.242667  1.126667  1.209333   1.209333   40201500
# 2010-07-14  1.196000  1.343333  1.184000  1.322667   1.322667   62928000
# 2010-07-15  1.329333  1.433333  1.266667  1.326000   1.326000   56097000
# ...

# %%
TSLA_data[['Open','Open : 30 Days Moving Average','Open : 50 Days Moving Average']].plot(figsize = (15,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Cumulative Moving Average

# %%
TSLA_data['Open'].expanding().mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## EMA : Exponential Moving Averages

# %%
###Smoothining factor = 0.1
TSLA_data['EMA_0.1'] = TSLA_data['Open'].ewm(alpha=0.1,adjust = False).mean()

# %%
TSLA_data[['Open','EMA_0.1']].plot(xlim = ['2023-01-01','2023-07-10'],figsize = (15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
###Smoothining factor = 0.3
TSLA_data['EMA_0.3'] = TSLA_data['Open'].ewm(alpha=0.3,adjust = False).mean()
TSLA_data[['Open','EMA_0.3']].plot(xlim = ['2023-01-01','2023-07-10'],figsize = (15,6))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # EWMA : Exponential Weighted Moving Averages

# %%
### you can calculate EWMA with Span
TSLA_data['EWMA_5_days'] = TSLA_data['Open'].ewm(span=5,adjust = False).mean()
TSLA_data[['Open','EWMA_5_days']].plot(xlim = ['2023-01-01','2023-07-10'],figsize = (15,6))
# Out:
# <Axes: xlabel='Date'>
